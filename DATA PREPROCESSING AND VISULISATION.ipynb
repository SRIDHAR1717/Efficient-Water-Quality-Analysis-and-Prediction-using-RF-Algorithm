# %% [markdown]
# # Importing The Necessary Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# %pip install seaborn

# %%
import seaborn as sns

# %% [markdown]
# # Reading The Dataset

# %%
df=pd.read_csv(r'Water_Quality_data.csv',encoding='ISO-8859-1',low_memory=False)
df
# Out:
#      ï»¿STATION CODE                                          LOCATIONS  \
# 0               1393               DAMANGANGA AT D/S OF MADHUBAN, DAMAN
# 1               1399  ZUARI AT D/S OF PT. WHERE KUMBARJRIA CANAL JOI...
# 2               1475                                ZUARI AT PANCHAWADI
# 3               3181                        RIVER ZUARI AT BORIM BRIDGE
# 4               3182                       RIVER ZUARI AT MARCAIM JETTY
# ...              ...                                                ...
# 1986            1330            TAMBIRAPARANI AT ARUMUGANERI, TAMILNADU
# 1987            1450  PALAR AT VANIYAMBADI WATER SUPPLY HEAD WORK, T...
# 1988            1403                 GUMTI AT U/S SOUTH TRIPURA,TRIPURA
# 1989            1404                GUMTI AT D/S SOUTH TRIPURA, TRIPURA
# 1990            1726   CHANDRAPUR, AGARTALA D/S OF HAORA RIVER, TRIPURA
#
#             STATE  Temp D.O. (mg/l)   PH CONDUCTIVITY (Âµmhos/cm)  \
# 0     DAMAN & DIU  30.6         6.7  7.5                      203
# 1             GOA  29.8         5.7  7.2                      189
# 2             GOA  29.5         6.3  6.9                      179
# 3             GOA  29.7         5.8  6.9                       64
# 4             GOA  29.5         5.8  7.3                       83
# ...           ...   ...         ...  ...                      ...
# 1986          NAN   NAN         7.9  738                      7.2
# 1987          NAN    29         7.5  585                      6.3
# 1988          NAN    28         7.6   98                      6.2
# 1989          NAN    28         7.7   91                      6.5
# 1990          NAN    29         7.6  110                      5.7
#
#      B.O.D. (mg/l) NITRATENAN N+ NITRITENANN (mg/l)  \
# 0              NAN                              0.1
# 1                2                              0.2
# 2              1.7                              0.1
# 3              3.8                              0.5
# 4              1.9                              0.4
# ...            ...                              ...
# 1986           2.7                            0.518
# 1987           2.6                            0.155
# 1988           1.2                              NAN
# 1989           1.3                              NAN
# 1990           1.1                              NAN
#
#      FECAL COLIFORM (MPN/100ml) TOTAL COLIFORM (MPN/100ml)Mean  year
# 0                            11                             27  2014
# 1                          4953                           8391  2014
# 2                          3243                           5330  2014
# 3                          5382                           8443  2014
# 4                          3428                           5500  2014
# ...                         ...                            ...   ...
# 1986                      0.518                            202  2003
# 1987                      0.155                            315  2003
# 1988                        NAN                            570  2003
# 1989                        NAN                            562  2003
# 1990                        NAN                            546  2003
#
# [1991 rows x 12 columns]

# %% [markdown]
# # head() command is used to display the top n records of the specified dataset.

# %%
df.head()
# Out:
#   ï»¿STATION CODE                                          LOCATIONS  \
# 0            1393               DAMANGANGA AT D/S OF MADHUBAN, DAMAN
# 1            1399  ZUARI AT D/S OF PT. WHERE KUMBARJRIA CANAL JOI...
# 2            1475                                ZUARI AT PANCHAWADI
# 3            3181                        RIVER ZUARI AT BORIM BRIDGE
# 4            3182                       RIVER ZUARI AT MARCAIM JETTY
#
#          STATE  Temp D.O. (mg/l)   PH CONDUCTIVITY (Âµmhos/cm) B.O.D. (mg/l)  \
# 0  DAMAN & DIU  30.6         6.7  7.5                      203           NAN
# 1          GOA  29.8         5.7  7.2                      189             2
# 2          GOA  29.5         6.3  6.9                      179           1.7
# 3          GOA  29.7         5.8  6.9                       64           3.8
# 4          GOA  29.5         5.8  7.3                       83           1.9
#
#   NITRATENAN N+ NITRITENANN (mg/l) FECAL COLIFORM (MPN/100ml)  \
# 0                              0.1                         11
# 1                              0.2                       4953
# 2                              0.1                       3243
# 3                              0.5                       5382
# 4                              0.4                       3428
#
#   TOTAL COLIFORM (MPN/100ml)Mean  year
# 0                             27  2014
# 1                           8391  2014
# 2                           5330  2014
# 3                           8443  2014
# 4                           5500  2014

# %% [markdown]
# # Analysis Of The Data

# %% [markdown]
# # info() method is used to get the columns in the dataset along with its properties

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1991 entries, 0 to 1990
# Data columns (total 12 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   ï»¿STATION CODE                   1991 non-null   object
#  1   LOCATIONS                         1991 non-null   object
#  2   STATE                             1991 non-null   object
#  3   Temp                              1991 non-null   object
#  4   D.O. (mg/l)                       1991 non-null   object
#  5   PH                                1991 non-null   object
#  6   CONDUCTIVITY (Âµmhos/cm)          1991 non-null   object
#  7   B.O.D. (mg/l)                     1991 non-null   object
#  8   NITRATENAN N+ NITRITENANN (mg/l)  1991 non-null   object
#  9   FECAL COLIFORM (MPN/100ml)        1991 non-null   object
#  10  TOTAL COLIFORM (MPN/100ml)Mean    1991 non-null   object
#  11  year                              1991 non-null   int64
# dtypes: int64(1), object(11)
# memory usage: 101.2+ KB

# %% [markdown]
# # Descriptive Statistics Of The Dataset

# %%
df.describe()
# Out:
#               year
# count  1991.000000
# mean   2010.038172
# std       3.057333
# min    2003.000000
# 25%    2008.000000
# 50%    2011.000000
# 75%    2013.000000
# max    2014.000000

# %% [markdown]
# # The Above Description shows only the Descriptive Statistics of the year column beacuse it is the only column which has the datatype 'int64'

# %%
df.shape
# Out:
# (1991, 12)

# %% [markdown]
# # The Dataset contains 1991 Rows and 12 Columns.

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# # Handling the Missing Values

# %%
df.isnull().any()
# Out:
# ï»¿STATION CODE                     False
# LOCATIONS                           False
# STATE                               False
# Temp                                False
# D.O. (mg/l)                         False
# PH                                  False
# CONDUCTIVITY (Âµmhos/cm)            False
# B.O.D. (mg/l)                       False
# NITRATENAN N+ NITRITENANN (mg/l)    False
# FECAL COLIFORM (MPN/100ml)          False
# TOTAL COLIFORM (MPN/100ml)Mean      False
# year                                False
# dtype: bool

# %%
df.isnull().sum()
# Out:
# ï»¿STATION CODE                     0
# LOCATIONS                           0
# STATE                               0
# Temp                                0
# D.O. (mg/l)                         0
# PH                                  0
# CONDUCTIVITY (Âµmhos/cm)            0
# B.O.D. (mg/l)                       0
# NITRATENAN N+ NITRITENANN (mg/l)    0
# FECAL COLIFORM (MPN/100ml)          0
# TOTAL COLIFORM (MPN/100ml)Mean      0
# year                                0
# dtype: int64

# %% [markdown]
# # Initially there is no Null Values present in the Dataset.

# %% [markdown]
# # Checking The Data Types Of The Columns

# %%
df.dtypes
# Out:
# ï»¿STATION CODE                     object
# LOCATIONS                           object
# STATE                               object
# Temp                                object
# D.O. (mg/l)                         object
# PH                                  object
# CONDUCTIVITY (Âµmhos/cm)            object
# B.O.D. (mg/l)                       object
# NITRATENAN N+ NITRITENANN (mg/l)    object
# FECAL COLIFORM (MPN/100ml)          object
# TOTAL COLIFORM (MPN/100ml)Mean      object
# year                                 int64
# dtype: object

# %% [markdown]
# # Here many numeric columns also has the data type of object.
# Let's convert the columns into float datatype.

# %%
df['Temp']=pd.to_numeric(df['Temp'],errors='coerce')
df['D.O. (mg/l)']=pd.to_numeric(df['D.O. (mg/l)'],errors='coerce')
df['PH']=pd.to_numeric(df['PH'],errors='coerce')
df['B.O.D. (mg/l)']=pd.to_numeric(df['B.O.D. (mg/l)'],errors='coerce')
df['CONDUCTIVITY (Âµmhos/cm)']=pd.to_numeric(df['CONDUCTIVITY (Âµmhos/cm)'],errors='coerce')
df['NITRATENAN N+ NITRITENANN (mg/l)']=pd.to_numeric(df['NITRATENAN N+ NITRITENANN (mg/l)'],errors='coerce')
df['TOTAL COLIFORM (MPN/100ml)Mean']=pd.to_numeric(df['TOTAL COLIFORM (MPN/100ml)Mean'],errors='coerce')

# %%
df.dtypes
# Out:
# ï»¿STATION CODE                      object
# LOCATIONS                            object
# STATE                                object
# Temp                                float64
# D.O. (mg/l)                         float64
# PH                                  float64
# CONDUCTIVITY (Âµmhos/cm)            float64
# B.O.D. (mg/l)                       float64
# NITRATENAN N+ NITRITENANN (mg/l)    float64
# FECAL COLIFORM (MPN/100ml)           object
# TOTAL COLIFORM (MPN/100ml)Mean      float64
# year                                  int64
# dtype: object

# %% [markdown]
# # Let's Check For The Missing Values Again.

# %%
df.isnull().any()
# Out:
# ï»¿STATION CODE                     False
# LOCATIONS                           False
# STATE                               False
# Temp                                 True
# D.O. (mg/l)                          True
# PH                                   True
# CONDUCTIVITY (Âµmhos/cm)             True
# B.O.D. (mg/l)                        True
# NITRATENAN N+ NITRITENANN (mg/l)     True
# FECAL COLIFORM (MPN/100ml)          False
# TOTAL COLIFORM (MPN/100ml)Mean       True
# year                                False
# dtype: bool

# %%
df.isnull().sum()
# Out:
# ï»¿STATION CODE                       0
# LOCATIONS                             0
# STATE                                 0
# Temp                                 92
# D.O. (mg/l)                          31
# PH                                    8
# CONDUCTIVITY (Âµmhos/cm)             25
# B.O.D. (mg/l)                        43
# NITRATENAN N+ NITRITENANN (mg/l)    225
# FECAL COLIFORM (MPN/100ml)            0
# TOTAL COLIFORM (MPN/100ml)Mean      132
# year                                  0
# dtype: int64

# %% [markdown]
# # Now some columns which have been converted to float datatype has some missing values.So, we have to replace the Null values using the mean or mode

# %%
df['Temp'].fillna(df['Temp'].mean(),inplace=True)
df['D.O. (mg/l)'].fillna(df['D.O. (mg/l)'].mean(),inplace=True)
df['PH'].fillna(df['PH'].mean(),inplace=True)
df['CONDUCTIVITY (Âµmhos/cm)'].fillna(df['CONDUCTIVITY (Âµmhos/cm)'].mean(),inplace=True)
df['B.O.D. (mg/l)'].fillna(df['B.O.D. (mg/l)'].mean(),inplace=True)
df['NITRATENAN N+ NITRITENANN (mg/l)'].fillna(df['NITRATENAN N+ NITRITENANN (mg/l)'].mean(),inplace=True)
df['TOTAL COLIFORM (MPN/100ml)Mean'].fillna(df['TOTAL COLIFORM (MPN/100ml)Mean'].mean(),inplace=True)
# Out:
# <ipython-input-17-2542f406c14e>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Temp'].fillna(df['Temp'].mean(),inplace=True)
# <ipython-input-17-2542f406c14e>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['D.O. (mg/l)'].fillna(df['D.O. (mg/l)'].mean(),inplace=True)
# <ipython-input-17-2542f406c14e>:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['PH'].fillna(df['PH'].mean(),inplace=True)
# <ipython-input-17-2542f406c14e>:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['CONDUCTIVITY (Âµmhos/cm)'].fillna(df['CONDUCTIVITY (Âµmhos/cm)'].mean(),inplace=True)
# <ipython-input-17-2542f406c14e>:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['B.O.D. (mg/l)'].fillna(df['B.O.D. (mg/l)'].mean(),inplace=True)
# <ipython-input-17-2542f406c14e>:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['NITRATENAN N+ NITRITENANN (mg/l)'].fillna(df['NITRATENAN N+ NITRITENANN (mg/l)'].mean(),inplace=True)
# <ipython-input-17-2542f406c14e>:7: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['TOTAL COLIFORM (MPN/100ml)Mean'].fillna(df['TOTAL COLIFORM (MPN/100ml)Mean'].mean(),inplace=True)

# %%
df.isnull().any()
# Out:
# ï»¿STATION CODE                     False
# LOCATIONS                           False
# STATE                               False
# Temp                                False
# D.O. (mg/l)                         False
# PH                                  False
# CONDUCTIVITY (Âµmhos/cm)            False
# B.O.D. (mg/l)                       False
# NITRATENAN N+ NITRITENANN (mg/l)    False
# FECAL COLIFORM (MPN/100ml)          False
# TOTAL COLIFORM (MPN/100ml)Mean      False
# year                                False
# dtype: bool

# %%
df.isnull().sum()
# Out:
# ï»¿STATION CODE                     0
# LOCATIONS                           0
# STATE                               0
# Temp                                0
# D.O. (mg/l)                         0
# PH                                  0
# CONDUCTIVITY (Âµmhos/cm)            0
# B.O.D. (mg/l)                       0
# NITRATENAN N+ NITRITENANN (mg/l)    0
# FECAL COLIFORM (MPN/100ml)          0
# TOTAL COLIFORM (MPN/100ml)Mean      0
# year                                0
# dtype: int64

# %% [markdown]
# # Now, There is no missing values present in any columns of the dataset.So, we have handled the Missing Values present in the dataset.

# %%
df.head()
# Out:
#   ï»¿STATION CODE                                          LOCATIONS  \
# 0            1393               DAMANGANGA AT D/S OF MADHUBAN, DAMAN
# 1            1399  ZUARI AT D/S OF PT. WHERE KUMBARJRIA CANAL JOI...
# 2            1475                                ZUARI AT PANCHAWADI
# 3            3181                        RIVER ZUARI AT BORIM BRIDGE
# 4            3182                       RIVER ZUARI AT MARCAIM JETTY
#
#          STATE  Temp  D.O. (mg/l)   PH  CONDUCTIVITY (Âµmhos/cm)  \
# 0  DAMAN & DIU  30.6          6.7  7.5                     203.0
# 1          GOA  29.8          5.7  7.2                     189.0
# 2          GOA  29.5          6.3  6.9                     179.0
# 3          GOA  29.7          5.8  6.9                      64.0
# 4          GOA  29.5          5.8  7.3                      83.0
#
#    B.O.D. (mg/l)  NITRATENAN N+ NITRITENANN (mg/l) FECAL COLIFORM (MPN/100ml)  \
# 0       6.940049                               0.1                         11
# 1       2.000000                               0.2                       4953
# 2       1.700000                               0.1                       3243
# 3       3.800000                               0.5                       5382
# 4       1.900000                               0.4                       3428
#
#    TOTAL COLIFORM (MPN/100ml)Mean  year
# 0                            27.0  2014
# 1                          8391.0  2014
# 2                          5330.0  2014
# 3                          8443.0  2014
# 4                          5500.0  2014

# %%
df.drop(["FECAL COLIFORM (MPN/100ml)"],axis=1,inplace=True)

# %%
df.head()
# Out:
#   ï»¿STATION CODE                                          LOCATIONS  \
# 0            1393               DAMANGANGA AT D/S OF MADHUBAN, DAMAN
# 1            1399  ZUARI AT D/S OF PT. WHERE KUMBARJRIA CANAL JOI...
# 2            1475                                ZUARI AT PANCHAWADI
# 3            3181                        RIVER ZUARI AT BORIM BRIDGE
# 4            3182                       RIVER ZUARI AT MARCAIM JETTY
#
#          STATE  Temp  D.O. (mg/l)   PH  CONDUCTIVITY (Âµmhos/cm)  \
# 0  DAMAN & DIU  30.6          6.7  7.5                     203.0
# 1          GOA  29.8          5.7  7.2                     189.0
# 2          GOA  29.5          6.3  6.9                     179.0
# 3          GOA  29.7          5.8  6.9                      64.0
# 4          GOA  29.5          5.8  7.3                      83.0
#
#    B.O.D. (mg/l)  NITRATENAN N+ NITRITENANN (mg/l)  \
# 0       6.940049                               0.1
# 1       2.000000                               0.2
# 2       1.700000                               0.1
# 3       3.800000                               0.5
# 4       1.900000                               0.4
#
#    TOTAL COLIFORM (MPN/100ml)Mean  year
# 0                            27.0  2014
# 1                          8391.0  2014
# 2                          5330.0  2014
# 3                          8443.0  2014
# 4                          5500.0  2014

# %% [markdown]
# # Renaming The Column Names in the Dataset For simplicity

# %%
df=df.rename(columns = {'D.O. (mg/l)':'do'})
df=df.rename(columns = {'CONDUCTIVITY (Âµmhos/cm)':'co'})
df=df.rename(columns = {'B.O.D. (mg/l)':'bod'})
df=df.rename(columns = {'NITRATENAN N+ NITRITENANN (mg/l)':'na'})
df=df.rename(columns =  {'TOTAL COLIFORM (MPN/100ml)Mean':'tc'})
df=df.rename(columns =  {'ï»¿STATION CODE':'station'})
df=df.rename(columns =  {'LOCATIONS':'location'})
df=df.rename(columns =  {'STATE':'state'})
df=df.rename(columns =  {'PH':'ph'})

# %%
df.head()
# Out:
#   station                                           location        state  \
# 0    1393               DAMANGANGA AT D/S OF MADHUBAN, DAMAN  DAMAN & DIU
# 1    1399  ZUARI AT D/S OF PT. WHERE KUMBARJRIA CANAL JOI...          GOA
# 2    1475                                ZUARI AT PANCHAWADI          GOA
# 3    3181                        RIVER ZUARI AT BORIM BRIDGE          GOA
# 4    3182                       RIVER ZUARI AT MARCAIM JETTY          GOA
#
#    Temp   do   ph     co       bod   na      tc  year
# 0  30.6  6.7  7.5  203.0  6.940049  0.1    27.0  2014
# 1  29.8  5.7  7.2  189.0  2.000000  0.2  8391.0  2014
# 2  29.5  6.3  6.9  179.0  1.700000  0.1  5330.0  2014
# 3  29.7  5.8  6.9   64.0  3.800000  0.5  8443.0  2014
# 4  29.5  5.8  7.3   83.0  1.900000  0.4  5500.0  2014

# %%
df.isnull().sum()
# Out:
# station     0
# location    0
# state       0
# Temp        0
# do          0
# ph          0
# co          0
# bod         0
# na          0
# tc          0
# year        0
# dtype: int64

# %% [markdown]
# # So, The Dataset has been read , analysed and preprocessing has been done successfully.

# %% [markdown]
# # Water Quality Index Calculation

# %% [markdown]
# # Calculation of pH (in range of 1 to 100)

# %%
df['npH']=df.ph.apply(lambda x: (100 if (8.5>=x>=7)  
                                 else(80 if  (8.6>=x>=8.5) or (6.9>=x>=6.8) 
                                      else(60 if (8.8>=x>=8.6) or (6.8>=x>=6.7) 
                                          else(40 if (9>=x>=8.8) or (6.7>=x>=6.5)
                                              else 0)))))

# %% [markdown]
# # Calculation of Dissolved Oxygen(in range of 1 to 100)

# %%
df['ndo']=df.do.apply(lambda x:(100 if (x>=6)  
                                 else(80 if  (6>=x>=5.1) 
                                      else(60 if (5>=x>=4.1)
                                          else(40 if (4>=x>=3) 
                                              else 0)))))

# %% [markdown]
# # Calculation of Total Coliform(in range of 1 to 100)

# %%
df['nco']=df.tc.apply(lambda x:(100 if (5>=x>=0)  
                                 else(80 if  (50>=x>=5) 
                                      else(60 if (500>=x>=50)
                                          else(40 if (10000>=x>=500) 
                                              else 0)))))

# %% [markdown]
# # Calculation of B.O.D - Biological Oxygen Demand (in range of 1 to 100)

# %%
df['nbdo']=df.bod.apply(lambda x:(100 if (3>=x>=0)  
                                 else(80 if  (6>=x>=3) 
                                      else(60 if (80>=x>=6)
                                          else(40 if (125>=x>=80) 
                                              else 0)))))

# %% [markdown]
# # Calculation of Electrical Conductivity (in range of 1 to 100)

# %%
df['nec']=df.co.apply(lambda x:(100 if (75>=x>=0)  
                                 else(80 if  (150>=x>=75) 
                                      else(60 if (225>=x>=150)
                                          else(40 if (300>=x>=225) 
                                              else 0)))))

# %% [markdown]
# # Calculation of Nitrate Content(in range of 1 to 100)

# %%
df['nna']=df.na.apply(lambda x:(100 if (20>=x>=0)  
                                 else(80 if  (50>=x>=20) 
                                      else(60 if (100>=x>=50)
                                          else(40 if (200>=x>=100) 
                                              else 0)))))

# %%
df.head()
# Out:
#   station                                           location        state  \
# 0    1393               DAMANGANGA AT D/S OF MADHUBAN, DAMAN  DAMAN & DIU
# 1    1399  ZUARI AT D/S OF PT. WHERE KUMBARJRIA CANAL JOI...          GOA
# 2    1475                                ZUARI AT PANCHAWADI          GOA
# 3    3181                        RIVER ZUARI AT BORIM BRIDGE          GOA
# 4    3182                       RIVER ZUARI AT MARCAIM JETTY          GOA
#
#    Temp   do   ph     co       bod   na      tc  year  npH  ndo  nco  nbdo  \
# 0  30.6  6.7  7.5  203.0  6.940049  0.1    27.0  2014  100  100   80    60
# 1  29.8  5.7  7.2  189.0  2.000000  0.2  8391.0  2014  100   80   40   100
# 2  29.5  6.3  6.9  179.0  1.700000  0.1  5330.0  2014   80  100   40   100
# 3  29.7  5.8  6.9   64.0  3.800000  0.5  8443.0  2014   80   80   40    80
# 4  29.5  5.8  7.3   83.0  1.900000  0.4  5500.0  2014  100   80   40   100
#
#    nec  nna
# 0   60  100
# 1   60  100
# 2   60  100
# 3  100  100
# 4   80  100

# %%
df.dtypes
# Out:
# station      object
# location     object
# state        object
# Temp        float64
# do          float64
# ph          float64
# co          float64
# bod         float64
# na          float64
# tc          float64
# year          int64
# npH           int64
# ndo           int64
# nco           int64
# nbdo          int64
# nec           int64
# nna           int64
# dtype: object

# %% [markdown]
# # Calculating Water Quality Index Value

# %%
df['wph']=df.npH * 0.165
df['wdo']=df.ndo * 0.281
df['wbdo']=df.nbdo * 0.234
df['wec']=df.nec* 0.009
df['wna']=df.nna * 0.028
df['wco']=df.nco * 0.281
df['wqi']=df.wph+df.wdo+df.wbdo+df.wec+df.wna+df.wco

# %%
df.head()
# Out:
#   station                                           location        state  \
# 0    1393               DAMANGANGA AT D/S OF MADHUBAN, DAMAN  DAMAN & DIU
# 1    1399  ZUARI AT D/S OF PT. WHERE KUMBARJRIA CANAL JOI...          GOA
# 2    1475                                ZUARI AT PANCHAWADI          GOA
# 3    3181                        RIVER ZUARI AT BORIM BRIDGE          GOA
# 4    3182                       RIVER ZUARI AT MARCAIM JETTY          GOA
#
#    Temp   do   ph     co       bod   na      tc  ...  nbdo  nec  nna   wph  \
# 0  30.6  6.7  7.5  203.0  6.940049  0.1    27.0  ...    60   60  100  16.5
# 1  29.8  5.7  7.2  189.0  2.000000  0.2  8391.0  ...   100   60  100  16.5
# 2  29.5  6.3  6.9  179.0  1.700000  0.1  5330.0  ...   100   60  100  13.2
# 3  29.7  5.8  6.9   64.0  3.800000  0.5  8443.0  ...    80  100  100  13.2
# 4  29.5  5.8  7.3   83.0  1.900000  0.4  5500.0  ...   100   80  100  16.5
#
#      wdo   wbdo   wec  wna    wco    wqi
# 0  28.10  14.04  0.54  2.8  22.48  84.46
# 1  22.48  23.40  0.54  2.8  11.24  76.96
# 2  28.10  23.40  0.54  2.8  11.24  79.28
# 3  22.48  18.72  0.90  2.8  11.24  69.34
# 4  22.48  23.40  0.72  2.8  11.24  77.14
#
# [5 rows x 24 columns]

# %% [markdown]
# # Calculating Overall Water Quality Index for Each Year

# %%
average=df.groupby('year')['wqi'].mean()

# %%
average
# Out:
# year
# 2003    66.239545
# 2004    61.290000
# 2005    73.762689
# 2006    72.909714
# 2007    74.233000
# 2008    73.506289
# 2009    74.456685
# 2010    75.454787
# 2011    76.666580
# 2012    79.496712
# 2013    76.494789
# 2014    77.839592
# Name: wqi, dtype: float64

# %%
df1=average.reset_index(level=0,inplace=False)
df1
# Out:
#     year        wqi
# 0   2003  66.239545
# 1   2004  61.290000
# 2   2005  73.762689
# 3   2006  72.909714
# 4   2007  74.233000
# 5   2008  73.506289
# 6   2009  74.456685
# 7   2010  75.454787
# 8   2011  76.666580
# 9   2012  79.496712
# 10  2013  76.494789
# 11  2014  77.839592

# %% [markdown]
# # Various Data Visualisations

# %% [markdown]
# # 1. Univariate Visualisations

# %%
for col in df.columns:
    if df.dtypes[col]=='float64'or df.dtypes[col]=='int64':
        sns.boxplot(x=df[col]).set(xlabel=col)
        plt.show()

# %%
for col in df.columns:
    if df.dtypes[col]=='float64':
        sns.distplot(x=df[col]).set(xlabel=col)
        plt.show()
# Out:
# <ipython-input-40-765ff466bb92>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=df[col]).set(xlabel=col)
# <ipython-input-40-765ff466bb92>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=df[col]).set(xlabel=col)
# <ipython-input-40-765ff466bb92>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=df[col]).set(xlabel=col)
# <ipython-input-40-765ff466bb92>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=df[col]).set(xlabel=col)
# <ipython-input-40-765ff466bb92>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=df[col]).set(xlabel=col)
# <ipython-input-40-765ff466bb92>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=df[col]).set(xlabel=col)
# <ipython-input-40-765ff466bb92>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=df[col]).set(xlabel=col)
# <ipython-input-40-765ff466bb92>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=df[col]).set(xlabel=col)
# <ipython-input-40-765ff466bb92>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=df[col]).set(xlabel=col)
# <ipython-input-40-765ff466bb92>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=df[col]).set(xlabel=col)
# <ipython-input-40-765ff466bb92>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=df[col]).set(xlabel=col)
# <ipython-input-40-765ff466bb92>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=df[col]).set(xlabel=col)
# <ipython-input-40-765ff466bb92>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=df[col]).set(xlabel=col)
# <ipython-input-40-765ff466bb92>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=df[col]).set(xlabel=col)

# %% [markdown]
# # 2. Bivariate Analysis

# %%
for col1 in df.columns:
    if df.dtypes[col1]=='float64':
        for col2 in ['wqi']:
            if df.dtypes[col2]=='float64':
                sns.boxplot(x=df[col1],y=df[col2]).set(xlabel=[col1],ylabel=[col2])
                plt.show()

# %%
for col1 in ['wph','wdo','wbdo','wec','wna','wco']:
    for col2 in ['wqi']:
        sns.jointplot(x=df[col1],y=df[col2])
        plt.show()

# %% [markdown]
# # Removing Unnecessary Columns in the Dataset which is used to calculate the Water Quality Index (WQI)

# %%
df.head()
# Out:
#   station                                           location        state  \
# 0    1393               DAMANGANGA AT D/S OF MADHUBAN, DAMAN  DAMAN & DIU
# 1    1399  ZUARI AT D/S OF PT. WHERE KUMBARJRIA CANAL JOI...          GOA
# 2    1475                                ZUARI AT PANCHAWADI          GOA
# 3    3181                        RIVER ZUARI AT BORIM BRIDGE          GOA
# 4    3182                       RIVER ZUARI AT MARCAIM JETTY          GOA
#
#    Temp   do   ph     co       bod   na      tc  ...  nbdo  nec  nna   wph  \
# 0  30.6  6.7  7.5  203.0  6.940049  0.1    27.0  ...    60   60  100  16.5
# 1  29.8  5.7  7.2  189.0  2.000000  0.2  8391.0  ...   100   60  100  16.5
# 2  29.5  6.3  6.9  179.0  1.700000  0.1  5330.0  ...   100   60  100  13.2
# 3  29.7  5.8  6.9   64.0  3.800000  0.5  8443.0  ...    80  100  100  13.2
# 4  29.5  5.8  7.3   83.0  1.900000  0.4  5500.0  ...   100   80  100  16.5
#
#      wdo   wbdo   wec  wna    wco    wqi
# 0  28.10  14.04  0.54  2.8  22.48  84.46
# 1  22.48  23.40  0.54  2.8  11.24  76.96
# 2  28.10  23.40  0.54  2.8  11.24  79.28
# 3  22.48  18.72  0.90  2.8  11.24  69.34
# 4  22.48  23.40  0.72  2.8  11.24  77.14
#
# [5 rows x 24 columns]

# %%
df.drop(['station','location','state'],axis = 1,inplace=True)
df.head()
# Out:
#    Temp   do   ph     co       bod   na      tc  year  npH  ndo  ...  nbdo  \
# 0  30.6  6.7  7.5  203.0  6.940049  0.1    27.0  2014  100  100  ...    60
# 1  29.8  5.7  7.2  189.0  2.000000  0.2  8391.0  2014  100   80  ...   100
# 2  29.5  6.3  6.9  179.0  1.700000  0.1  5330.0  2014   80  100  ...   100
# 3  29.7  5.8  6.9   64.0  3.800000  0.5  8443.0  2014   80   80  ...    80
# 4  29.5  5.8  7.3   83.0  1.900000  0.4  5500.0  2014  100   80  ...   100
#
#    nec  nna   wph    wdo   wbdo   wec  wna    wco    wqi
# 0   60  100  16.5  28.10  14.04  0.54  2.8  22.48  84.46
# 1   60  100  16.5  22.48  23.40  0.54  2.8  11.24  76.96
# 2   60  100  13.2  28.10  23.40  0.54  2.8  11.24  79.28
# 3  100  100  13.2  22.48  18.72  0.90  2.8  11.24  69.34
# 4   80  100  16.5  22.48  23.40  0.72  2.8  11.24  77.14
#
# [5 rows x 21 columns]

# %% [markdown]
# # 3. Multivariate Analysis

# %%
df.corr
# Out:
# <bound method DataFrame.corr of            Temp   do     ph     co       bod        na      tc  year  npH  \
# 0     30.600000  6.7    7.5  203.0  6.940049  0.100000    27.0  2014  100
# 1     29.800000  5.7    7.2  189.0  2.000000  0.200000  8391.0  2014  100
# 2     29.500000  6.3    6.9  179.0  1.700000  0.100000  5330.0  2014   80
# 3     29.700000  5.8    6.9   64.0  3.800000  0.500000  8443.0  2014   80
# 4     29.500000  5.8    7.3   83.0  1.900000  0.400000  5500.0  2014  100
# ...         ...  ...    ...    ...       ...       ...     ...   ...  ...
# 1986  26.209814  7.9  738.0    7.2  2.700000  0.518000   202.0  2003    0
# 1987  29.000000  7.5  585.0    6.3  2.600000  0.155000   315.0  2003    0
# 1988  28.000000  7.6   98.0    6.2  1.200000  1.623079   570.0  2003    0
# 1989  28.000000  7.7   91.0    6.5  1.300000  1.623079   562.0  2003    0
# 1990  29.000000  7.6  110.0    5.7  1.100000  1.623079   546.0  2003    0
#
#       ndo  ...  nbdo  nec  nna   wph    wdo   wbdo   wec  wna    wco    wqi
# 0     100  ...    60   60  100  16.5  28.10  14.04  0.54  2.8  22.48  84.46
# 1      80  ...   100   60  100  16.5  22.48  23.40  0.54  2.8  11.24  76.96
# 2     100  ...   100   60  100  13.2  28.10  23.40  0.54  2.8  11.24  79.28
# 3      80  ...    80  100  100  13.2  22.48  18.72  0.90  2.8  11.24  69.34
# 4      80  ...   100   80  100  16.5  22.48  23.40  0.72  2.8  11.24  77.14
# ...   ...  ...   ...  ...  ...   ...    ...    ...   ...  ...    ...    ...
# 1986  100  ...   100  100  100   0.0  28.10  23.40  0.90  2.8  16.86  72.06
# 1987  100  ...   100  100  100   0.0  28.10  23.40  0.90  2.8  16.86  72.06
# 1988  100  ...   100  100  100   0.0  28.10  23.40  0.90  2.8  11.24  66.44
# 1989  100  ...   100  100  100   0.0  28.10  23.40  0.90  2.8  11.24  66.44
# 1990  100  ...   100  100  100   0.0  28.10  23.40  0.90  2.8  11.24  66.44
#
# [1991 rows x 21 columns]>

# %%
df.drop(['Temp','nbdo',"nec","nna","wph","wdo","wbdo","wec","wna","wco","npH","ndo","nco"],axis = 1,inplace=True)
df.head()
# Out:
#     do   ph     co       bod   na      tc  year    wqi
# 0  6.7  7.5  203.0  6.940049  0.1    27.0  2014  84.46
# 1  5.7  7.2  189.0  2.000000  0.2  8391.0  2014  76.96
# 2  6.3  6.9  179.0  1.700000  0.1  5330.0  2014  79.28
# 3  5.8  6.9   64.0  3.800000  0.5  8443.0  2014  69.34
# 4  5.8  7.3   83.0  1.900000  0.4  5500.0  2014  77.14

# %%
df.corr()
# Out:
#             do        ph        co       bod        na        tc      year  \
# do    1.000000  0.034824 -0.165684 -0.248431 -0.190797 -0.142953 -0.068800
# ph    0.034824  1.000000 -0.017843  0.041405 -0.006608 -0.002123 -0.128234
# co   -0.165684 -0.017843  1.000000  0.101544  0.056668  0.003415  0.026650
# bod  -0.248431  0.041405  0.101544  1.000000  0.126073  0.164393 -0.058320
# na   -0.190797 -0.006608  0.056668  0.126073  1.000000 -0.000882  0.018801
# tc   -0.142953 -0.002123  0.003415  0.164393 -0.000882  1.000000  0.036141
# year -0.068800 -0.128234  0.026650 -0.058320  0.018801  0.036141  1.000000
# wqi   0.678756 -0.059461 -0.104916 -0.349332 -0.265051 -0.133946  0.180629
#
#            wqi
# do    0.678756
# ph   -0.059461
# co   -0.104916
# bod  -0.349332
# na   -0.265051
# tc   -0.133946
# year  0.180629
# wqi   1.000000

# %%
sns.heatmap(df.corr())
# Out:
# <AxesSubplot:>
